# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit25587/import-data/blob/master/Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This *is* **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item in list:
#     print(item)
# ```

# %% [markdown]
# ![Slide8.PNG](data:image/png;base64,...)

# %% [markdown]
# [Google Search](https://www.google.com)

# %% [markdown]
# 1.   first
# 2.   Second
#
# ghsdfjusg
#
# > dgfhigIndented block
#
#
# sjgkfd

# %% [markdown]
# Hello

# %% [markdown]
# $ ax^2 + bx + c =0 $

# %% [markdown]
# $$x1 = \frac{-b + \sqrt{b^2 - 4ac}}{2a}$$
